# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
mnist = tf.keras.datasets.mnist

(x_train, y_train),(x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://s3.amazonaws.com/img-datasets/mnist.npz
# 11493376/11490434 [==============================] - 3s 0us/step
# 11501568/11490434 [==============================] - 3s 0us/step

# %%
tr_data = x_train
ts_data = x_test
tr_labels = []
ts_labels = []
for ytr in y_train:
    tr = np.zeros([10])
    tr[ytr] = 1.0
    tr_labels.append(tr)
for yts in y_test:
    ts = np.zeros([10])
    ts[yts] = 1.0
    ts_labels.append(ts)

tr_data = np.array(tr_data,dtype=np.float32)
ts_data = np.array(ts_data,dtype=np.float32)
tr_labels = np.array(tr_labels,dtype=np.float32)
ts_labels = np.array(ts_labels,dtype=np.float32)

# %%
tf.reset_default_graph()

# %%
x = tf.placeholder(tf.float32,[None,28,28])
y = tf.placeholder(tf.float32,[None,10])

W1 = tf.Variable(tf.random_normal([784,64],stddev=0.1))
b1 = tf.Variable(tf.random_normal([64],stddev=0.1))

W2 = tf.Variable(tf.random_normal([64,10],stddev=0.1))
b2 = tf.Variable(tf.random_normal([10],stddev=0.1))

x_ = tf.reshape(x,[-1,784])
x1 = tf.matmul(x_,W1)+b1
x1_a = tf.nn.tanh(x1)
x2 = tf.matmul(x1_a,W2)+b2
output = tf.nn.softmax(x2)

loss = tf.losses.softmax_cross_entropy(y,output)

train_op = tf.train.AdamOptimizer(learning_rate=0.001).minimize(loss)

# %%
sess = tf.Session()
sess.run(tf.global_variables_initializer())

# %%
num_iter = 5000
for i in range(num_iter):
    indices = np.random.randint(len(tr_data),size=[64])
    b_data = tr_data[indices]
    b_labels = tr_labels[indices]
    
    sess.run(train_op,feed_dict={x:b_data,y:b_labels})
    
    if i % (num_iter/10) == 0:
        print("LOSS : " + str(sess.run(loss,feed_dict={x:tr_data,y:tr_labels})))
        preds = sess.run(output,feed_dict={x:tr_data})
        print("ACC : " + str(np.mean(np.equal(np.argmax(preds,axis=1),np.argmax(tr_labels,axis=1)))))
# Out:
# LOSS : 2.3030164
# ACC : 0.10945
# LOSS : 1.7040302
# ACC : 0.8125166666666667
# LOSS : 1.6543516
# ACC : 0.845
# LOSS : 1.6186204
# ACC : 0.86585
# LOSS : 1.6273671
# ACC : 0.8556666666666667
# LOSS : 1.6197857
# ACC : 0.8661
# LOSS : 1.6085503
# ACC : 0.8708333333333333
# LOSS : 1.6040305
# ACC : 0.87305
# LOSS : 1.5986456
# ACC : 0.8792666666666666
# LOSS : 1.5925888
# ACC : 0.8805833333333334

# %%
plt.imshow(tr_data[0])
plt.show()

# %%
print(sess.run(tf.argmax(output,axis=1),feed_dict={x:[tr_data[0]]}))
# Out:
# [5]

# %%
pic_grad = sess.run(tf.gradients(output[:,5],x_),feed_dict={x:[tr_data[0]]})[0][0]

# %%
pic_grad
# Out:
# array([-9.10326719e-07,  5.82115172e-06,  1.07812275e-05,  3.28993360e-06,
#         1.12983216e-05,  1.50284552e-06,  1.12032994e-05, -2.64263940e-06,
#         2.95148629e-06, -1.83748534e-06, -3.64105722e-06,  2.34498225e-06,
#         2.67298492e-06,  5.70038765e-06,  7.74123873e-06, -4.91386800e-07,
#         4.23474785e-06, -2.61057789e-06, -7.49285391e-07,  1.86205580e-06,
#         1.61363062e-06,  3.32212622e-08, -4.30804812e-06, -5.20188280e-07,
#        -2.68273720e-06, -8.85796271e-06, -3.99099872e-06, -7.60038120e-06,
#        -2.16181775e-06,  1.33068061e-05,  9.29037833e-06, -4.05732681e-06,
#        -1.03497496e-06,  3.85082421e-06, -7.58960550e-06, -4.93094649e-06,
#         1.62344168e-06,  2.85692022e-06, -4.65245103e-06,  7.15558826e-07,
#        -1.85074782e-06, -6.72887109e-06,  5.83033398e-06, -1.25472370e-05,
#        -1.04126684e-05,  1.37520715e-06,  1.10809572e-06, -9.20907212e-07,
#        -9.40390510e-06, -6.71666703e-06,  2.41730208e-06,  3.30682440e-07,
#         6.71033263e-07, -8.28809061e-06, -5.76671823e-07,  3.06157904e-06,
#        -1.30083706e-07,  3.10737755e-06, -6.12572012e-06,  3.22237611e-06,
#        -2.96263920e-06, -4.28902285e-06, -4.34832646e-06,  2.66315760e-06],
#       dtype=float32)

# %%
plt.imshow(np.reshape(np.absolute(pic_grad),[28,28]))
plt.show()

# %%
# GET UNIQUE VALUES OF EACH PIXEL IN DATASET

unique_vals = []
for pixel in range(784):
    pixel = np.reshape(tr_data,[-1,784])[:,pixel]
    unique_vals.append(np.unique(pixel))

# %%
outputs = []
output_ = output[:,5]
for i,uv in enumerate(np.transpose(np.reshape(tr_data[:1000],[-1,784]))):
    o_ = []
    if i % 50 == 0:
        print(i)
    for xnew in uv:
        dat = np.array(tr_data[0])
        dat[i/28][i%28] = xnew
        op_ = sess.run(output_,feed_dict={x:[dat]})[0]
        o_.append(op_)
    outputs.append(o_)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750

# %%
val = sess.run(output[:,5],feed_dict={x:[tr_data[0]]})[0]
delta = []
abs_delta = []
for op in outputs:
    if len(op) == 1:
        delta.append(0.0)
        abs_delta.append(1.0)
    else:
        delta.append(np.mean(val-np.array(op)))
        j = np.mean(np.absolute(val-np.array(op)))
        if j == 0:
            abs_delta.append(1.0)
        else:
            abs_delta.append(j)
delta = np.array(delta)
abs_delta = np.array(abs_delta)

# %%
a = delta/abs_delta

# %%
fig, ax = plt.subplots()
im = ax.imshow(np.reshape(delta,[28,28]))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel(rotation=-90, va="bottom")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-a7fb9b236385> in <module>()
#       2 im = ax.imshow(np.reshape(delta,[28,28]))
#       3 cbar = ax.figure.colorbar(im, ax=ax)
# ----> 4 cbar.ax.set_ylabel(rotation=-90, va="bottom")
#
# TypeError: set_ylabel() takes at least 2 arguments (1 given)

# %%
plt.imshow(np.reshape(np.where(delta>0.2,1.0,0.0),[28,28]))
plt.show()

# %%
plt.imshow(tr_data[0]*np.reshape(np.where(delta>0.2,1.0,0.0),[28,28]))
plt.show()

# %%
sess.run(output[:,5],feed_dict={x:[tr_data[0]*np.reshape(np.where(delta>0.2,1.0,0.0),[28,28])]})
# Out:
# array([0.99963737], dtype=float32)

# %%
sess.run(output[:,5],feed_dict={x:[tr_data[0]-tr_data[0]*np.reshape(np.where(delta>0.2,1.0,0.0),[28,28])]})
# Out:
# array([0.02876876], dtype=float32)

# %%
plt.imshow(tr_data[2])
plt.show()

# %%
# GET UNIQUE VALUES OF EACH PIXEL IN DATASET

unique_vals = []
for pixel in range(784):
    pixel = np.reshape(tr_data,[-1,784])[:,pixel]
    unique_vals.append(np.unique(pixel))

# %%
outputs = []
output_ = output[:,4]
for i,uv in enumerate(np.transpose(np.reshape(tr_data[:1000],[-1,784]))):
    o_ = []
    if i % 50 == 0:
        print(i)
    for xnew in uv:
        dat = np.array(tr_data[2])
        dat[i/28][i%28] = xnew
        op_ = sess.run(output_,feed_dict={x:[dat]})[0]
        o_.append(op_)
    outputs.append(o_)
# Out:
# 0
# 50
# 100
# 150

# %%
val = sess.run(output[:,4],feed_dict={x:[tr_data[2]]})[0]
delta = []
abs_delta = []
for op in outputs:
    if len(op) == 1:
        delta.append(0.0)
        abs_delta.append(1.0)
    else:
        delta.append(np.mean(val-np.array(op)))
        j = np.mean(np.absolute(val-np.array(op)))
        if j == 0:
            abs_delta.append(1.0)
        else:
            abs_delta.append(j)
delta = np.array(delta)
abs_delta = np.array(abs_delta)

# %%
fig, ax = plt.subplots()
im = ax.imshow(np.reshape(delta,[28,28]))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel(rotation=-90, va="bottom")

# %%
plt.imshow(np.reshape(np.where(delta>0,1.0,0.0),[28,28]))
plt.show()

# %%
plt.imshow(tr_data[2]*np.reshape(np.where(delta>0.01,1.0,0.0),[28,28]))
plt.show()

# %%
sess.run(output[:,4],feed_dict={x:[tr_data[2]*np.reshape(np.where(delta>0,1.0,0.0),[28,28])]})
# Out:
# array([0.9999324], dtype=float32)

# %%
plt.imshow(tr_data[0])
plt.show()

# %%
# GET UNIQUE VALUES OF EACH PIXEL IN DATASET

unique_vals = []
for pixel in range(784):
    pixel = np.reshape(tr_data,[-1,784])[:,pixel]
    unique_vals.append(np.unique(pixel))

# %%
outputs = []
output_ = output[:,5]
for i,uv in enumerate(np.transpose(np.reshape(tr_data[:1000],[-1,784]))):
    o_ = []
    if i % 50 == 0:
        print(i)
    for xnew in uv:
        dat = np.array(tr_data[0])
        dat[i/28][i%28] = xnew
        op_ = sess.run(output_,feed_dict={x:[dat]})[0]
        o_.append(op_)
    outputs.append(o_)
# Out:
# 0
# 50
# 100
# 150
# 200
# 250
# 300
# 350
# 400
# 450
# 500
# 550
# 600
# 650
# 700
# 750

# %%
val = sess.run(output[:,5],feed_dict={x:[tr_data[0]]})[0]
delta = []
abs_delta = []
for op in outputs:
    if len(op) == 1:
        delta.append(0.0)
        abs_delta.append(1.0)
    else:
        delta.append(np.mean(val-np.array(op)))
        j = np.mean(np.absolute(val-np.array(op)))
        if j == 0:
            abs_delta.append(1.0)
        else:
            abs_delta.append(j)
delta = np.array(delta)
abs_delta = np.array(abs_delta)

# %%
fig, ax = plt.subplots()
im = ax.imshow(np.reshape(delta,[28,28]))
cbar = ax.figure.colorbar(im, ax=ax)
cbar.ax.set_ylabel(rotation=-90, va="bottom")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-a7fb9b236385> in <module>()
#       2 im = ax.imshow(np.reshape(delta,[28,28]))
#       3 cbar = ax.figure.colorbar(im, ax=ax)
# ----> 4 cbar.ax.set_ylabel(rotation=-90, va="bottom")
#
# TypeError: set_ylabel() takes at least 2 arguments (1 given)

# %%
plt.imshow(np.reshape(np.where(delta>0.2,1.0,0.0),[28,28]))
plt.show()

# %%
plt.imshow(tr_data[0]*np.reshape(np.where(delta>0.2,1.0,0.0),[28,28]))
plt.show()
